# %%
# !pip install pymorphy2 
# !pip install --upgrade datasets
# !pip install peft
# Out:
# Collecting pymorphy2
#   Downloading pymorphy2-0.9.1-py3-none-any.whl.metadata (3.6 kB)
# Collecting dawg-python>=0.7.1 (from pymorphy2)
#   Downloading DAWG_Python-0.7.2-py2.py3-none-any.whl.metadata (7.0 kB)
# Collecting pymorphy2-dicts-ru<3.0,>=2.4 (from pymorphy2)
#   Downloading pymorphy2_dicts_ru-2.4.417127.4579844-py2.py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: docopt>=0.6 in /opt/conda/lib/python3.10/site-packages (from pymorphy2) (0.6.2)
# Downloading pymorphy2-0.9.1-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 kB 1.8 MB/s eta 0:00:00
# Downloading DAWG_Python-0.7.2-py2.py3-none-any.whl (11 kB)
# Downloading pymorphy2_dicts_ru-2.4.417127.4579844-py2.py3-none-any.whl (8.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 59.3 MB/s eta 0:00:00
# Installing collected packages: pymorphy2-dicts-ru, dawg-python, pymorphy2
# Successfully installed dawg-python-0.7.2 pymorphy2-0.9.1 pymorphy2-dicts-ru-2.4.417127.4579844
# Requirement already satisfied: datasets in /opt/conda/lib/python3.10/site-packages (3.0.1)
# Collecting datasets
#   Downloading datasets-3.1.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from datasets) (3.15.1)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /opt/conda/lib/python3.10/site-packages (from datasets) (16.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /opt/conda/lib/python3.10/site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /opt/conda/lib/python3.10/site-packages (from datasets) (4.66.4)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.10/site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess<0.70.17 in /opt/conda/lib/python3.10/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from datasets) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from datasets) (0.25.1)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from datasets) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->datasets) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Downloading datasets-3.1.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 7.8 MB/s eta 0:00:00
# Installing collected packages: datasets
#   Attempting uninstall: datasets
#     Found existing installation: datasets 3.0.1
#     Uninstalling datasets-3.0.1:
#       Successfully uninstalled datasets-3.0.1
# Successfully installed datasets-3.1.0
# Collecting peft
#   Downloading peft-0.13.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from peft) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from peft) (21.3)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from peft) (5.9.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from peft) (6.0.2)
# Requirement already satisfied: torch>=1.13.0 in /opt/conda/lib/python3.10/site-packages (from peft) (2.4.0)
# Requirement already satisfied: transformers in /opt/conda/lib/python3.10/site-packages (from peft) (4.45.1)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from peft) (4.66.4)
# Requirement already satisfied: accelerate>=0.21.0 in /opt/conda/lib/python3.10/site-packages (from peft) (0.34.2)
# Requirement already satisfied: safetensors in /opt/conda/lib/python3.10/site-packages (from peft) (0.4.5)
# Requirement already satisfied: huggingface-hub>=0.17.0 in /opt/conda/lib/python3.10/site-packages (from peft) (0.25.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.17.0->peft) (3.15.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.17.0->peft) (2024.6.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.17.0->peft) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.17.0->peft) (4.12.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->peft) (3.1.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.13.0->peft) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.13.0->peft) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.13.0->peft) (3.1.4)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers->peft) (2024.5.15)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /opt/conda/lib/python3.10/site-packages (from transformers->peft) (0.20.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.13.0->peft) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.17.0->peft) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.17.0->peft) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.17.0->peft) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.17.0->peft) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.13.0->peft) (1.3.0)
# Downloading peft-0.13.2-py3-none-any.whl (320 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.7/320.7 kB 5.7 MB/s eta 0:00:00
# Installing collected packages: peft
# Successfully installed peft-0.13.2

# %%
import pandas as pd

import torch
from transformers import AutoModelForSequenceClassification, BertTokenizerFast, Trainer, TrainingArguments
from peft import LoraConfig

from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
import datasets

from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
stop_words = stopwords.words("russian")

import re

import pymorphy2
morph = pymorphy2.MorphAnalyzer()
# Out:
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def clean_text(text):
    # Remove URLs, numbers, and special characters
    text = re.sub(r'http\S+|www\S+|https\S+', '', text, flags=re.MULTILINE)  # URLs
    text = re.sub(r'\d+', '', text)  # Numbers
    text = re.sub(r'[^\w\s]', '', text)  # Special characters
    return text

def preprocess_text(text):
    tokens = nltk.word_tokenize(text.lower())
    # remove stop words
    tokens = [word for word in tokens if word.isalpha() and word not in stop_words]
    # lemmatize
    def lemmatize(tokens):
        return [morph.parse(word)[0].normal_form for word in tokens]
    tokens = lemmatize(tokens)
    return ' '.join(tokens)

def all_preprocessing(df):
    df['text'] = df['text'].apply(clean_text)
    df['text'] = df['text'].apply(preprocess_text)
    return df

# %%
import wandb

wandb.login(key='b123af3ff1bc7e54569d0976c6405a5b3b6d2902')
# Out:
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
df = pd.read_csv('/kaggle/input/wb_winter_24/train.csv', index_col='ID')
#df = all_preprocessing(df)
df.head()
# Out:
#                                                  text  label
# ID
# 0   Брюки отличные, качественные, но к сожалению к...      0
# 1   Отличный аппарат, в комплекте кабель и работет...      0
# 2                             Супер 👍 спасибо большое      0
# 3   Получил быстро данные наушники! К наушникам пр...      0
# 4                  Всё дошло в целости и сохранности)      0

# %% [markdown]
# # Prepare dataset

# %%
# Split dataset into training and validation
train_texts, train_labels = df['text'].tolist(), df['label'].tolist()
tokenizer = BertTokenizerFast.from_pretrained('blanchefort/rubert-base-cased-sentiment')

# Create a custom dataset class
class CustomDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_length=256):
        self.texts = texts
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_length = max_length

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        text = self.texts[idx]
        label = self.labels[idx]
        encoding = self.tokenizer(
            text, padding='max_length', truncation=True, max_length=self.max_length, return_tensors="pt"
        )
        return {
            'input_ids': encoding['input_ids'].flatten(),
            'attention_mask': encoding['attention_mask'].flatten(),
            'labels': torch.tensor(label, dtype=torch.long)
        }

# Prepare datasets
train_dataset = CustomDataset(train_texts, train_labels, tokenizer)

# Define compute metrics function
def compute_metrics(p):
    preds = p.predictions.argmax(-1)
    return {
        'accuracy': accuracy_score(p.label_ids, preds),
        'f1': f1_score(p.label_ids, preds, average='weighted'),
        'precision': precision_score(p.label_ids, preds, average='weighted'),
        'recall': recall_score(p.label_ids, preds, average='weighted')
    }
# Out:
# tokenizer_config.json:   0%|          | 0.00/499 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/1.40M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/943 [00:00<?, ?B/s]

# %% [markdown]
# # BERT + LoRA Trainer

# %%
train_dataset = datasets.Dataset.from_pandas(df)

# Tokenization (use your tokenizer)
def tokenize_function(examples):
    tokenized = tokenizer(examples['text'], padding='max_length', truncation=True, max_length=128)
    return tokenized

# Tokenize the datasets
train_dataset = train_dataset.map(tokenize_function, batched=True)
# Out:
# Map:   0%|          | 0/240159 [00:00<?, ? examples/s]

# %%
device = "cuda:0" if torch.cuda.is_available() else "cpu"

model = AutoModelForSequenceClassification.from_pretrained(
    'blanchefort/rubert-base-cased-sentiment', num_labels=2, ignore_mismatched_sizes=True  # Assuming binary classification
)

lora_config = LoraConfig(
    r=16,  # LoRA rank
    lora_alpha=16,
    lora_dropout=0.1,
    target_modules=["query", "value"]  # LoRA will only apply to these modules in the model
)

# Wrap the model with LoRA
model.add_adapter(lora_config, adapter_name='adapter')
model.to(device)
model.train()

# Print each layer's training status
for name, param in model.named_parameters():
    if name.startswith('classifier'):
        param.requires_grad = True

for name, param in model.named_parameters():
    print(f"Layer: {name} | Trainable: {param.requires_grad}")

total_params = sum(p.numel() for p in model.parameters())
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"Total parameters: {total_params}")
print(f"Trainable parameters: {trainable_params}")
# Out:
# model.safetensors:   0%|          | 0.00/711M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at blanchefort/rubert-base-cased-sentiment and are newly initialized because the shapes did not match:
# - classifier.bias: found shape torch.Size([3]) in the checkpoint and torch.Size([2]) in the model instantiated
# - classifier.weight: found shape torch.Size([3, 768]) in the checkpoint and torch.Size([2, 768]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Layer: bert.embeddings.word_embeddings.weight | Trainable: False
# Layer: bert.embeddings.position_embeddings.weight | Trainable: False
# Layer: bert.embeddings.token_type_embeddings.weight | Trainable: False
# Layer: bert.embeddings.LayerNorm.weight | Trainable: False
# Layer: bert.embeddings.LayerNorm.bias | Trainable: False
# Layer: bert.encoder.layer.0.attention.self.query.base_layer.weight | Trainable: False
# Layer: bert.encoder.layer.0.attention.self.query.base_layer.bias | Trainable: False
# Layer: bert.encoder.layer.0.attention.self.query.lora_A.adapter.weight | Trainable: True
# Layer: bert.encoder.layer.0.attention.self.query.lora_B.adapter.weight | Trainable: True
# Layer: bert.encoder.layer.0.attention.self.key.weight | Trainable: False
# Layer: bert.encoder.layer.0.attention.self.key.bias | Trainable: False
# Layer: bert.encoder.layer.0.attention.self.value.base_layer.weight | Trainable: False
# Layer: bert.encoder.layer.0.attention.self.value.base_layer.bias | Trainable: False
# Layer: bert.encoder.layer.0.attention.self.value.lora_A.adapter.weight | Trainable: True
# Layer: bert.encoder.layer.0.attention.self.value.lora_B.adapter.weight | Trainable: True
# Layer: bert.encoder.layer.0.attention.output.dense.weight | Trainable: False
# Layer: bert.encoder.layer.0.attention.output.dense.bias | Trainable: False
# Layer: bert.encoder.layer.0.attention.output.LayerNorm.weight | Trainable: False
# Layer: bert.encoder.layer.0.attention.output.LayerNorm.bias | Trainable: False
# Layer: bert.encoder.layer.0.intermediate.dense.weight | Trainable: False
# Layer: bert.encoder.layer.0.intermediate.dense.bias | Trainable: False
# Layer: bert.encoder.layer.0.output.dense.weight | Trainable: False
# Layer: bert.encoder.layer.0.output.dense.bias | Trainable: False
# Layer: bert.encoder.layer.0.output.LayerNorm.weight | Trainable: False
# Layer: bert.encoder.layer.0.output.LayerNorm.bias | Trainable: False
# Layer: bert.encoder.layer.1.attention.self.query.base_layer.weight | Trainable: False
# Layer: bert.encoder.layer.1.attention.self.query.base_layer.bias | Trainable: False
# Layer: bert.encoder.layer.1.attention.self.query.lora_A.adapter.weight | Trainable: True
# Layer: bert.encoder.layer.1.attention.self.query.lora_B.adapter.weight | Trainable: True
# Layer: bert.encoder.layer.1.attention.self.key.weight | Trainable: False
# Layer: bert.encoder.layer.1.attention.self.key.bias | Trainable: False
# Layer: bert.encoder.layer.1.attention.self.value.base_layer.weight | Trainable: False
# Layer: bert.encoder.layer.1.attention.self.value.base_layer.bias | Trainable: False
# Layer: bert.encoder.layer.1.attention.self.value.lora_A.adapter.weight | Trainable: True
# Layer: bert.encoder.layer.1.attention.self.value.lora_B.adapter.weight | Trainable: True
# Layer: bert.encoder.layer.1.attention.output.dense.weight | Trainable: False
# Layer: bert.encoder.layer.1.attention.output.dense.bias | Trainable: False
# Layer: bert.encoder.layer.1.attention.output.LayerNorm.weight | Trainable: False
# Layer: bert.encoder.layer.1.attention.output.LayerNorm.bias | Trainable: False
# Layer: bert.encoder.layer.1.intermediate.dense.weight | Trainable: False
# Layer: bert.encoder.layer.1.intermediate.dense.bias | Trainable: False
# Layer: bert.encoder.layer.1.output.dense.weight | Trainable: False
# Layer: bert.encoder.layer.1.output.dense.bias | Trainable: False
# Layer: bert.encoder.layer.1.output.LayerNorm.weight | Trainable: False
# Layer: bert.encoder.layer.1.output.LayerNorm.bias | Trainable: False
# Layer: bert.encoder.layer.2.attention.self.query.base_layer.weight | Trainable: False
# Layer: bert.encoder.layer.2.attention.self.query.base_layer.bias | Trainable: False
# Layer: bert.encoder.layer.2.attention.self.query.lora_A.adapter.weight | Trainable: True
# Layer: bert.encoder.layer.2.attention.self.query.lora_B.adapter.weight | Trainable: True
# Layer: bert.encoder.layer.2.attention.self.key.weight | Trainable: False
# Layer: bert.encoder.layer.2.attention.self.key.bias | Trainable: False
# Layer: bert.encoder.layer.2.attention.self.value.base_layer.weight | Trainable: False
# Layer: bert.encoder.layer.2.attention.self.value.base_layer.bias | Trainable: False
# Layer: bert.encoder.layer.2.attention.self.value.lora_A.adapter.weight | Trainable: True
# Layer: bert.encoder.layer.2.attention.self.value.lora_B.adapter.weight | Trainable: True
# Layer: bert.encoder.layer.2.attention.output.dense.weight | Trainable: False
# Layer: bert.encoder.layer.2.attention.output.dense.bias | Trainable: False
# Layer: bert.encoder.layer.2.attention.output.LayerNorm.weight | Trainable: False
# Layer: bert.encoder.layer.2.attention.output.LayerNorm.bias | Trainable: False
# Layer: bert.encoder.layer.2.intermediate.dense.weight | Trainable: False
# Layer: bert.encoder.layer.2.intermediate.dense.bias | Trainable: False
# Layer: bert.encoder.layer.2.output.dense.weight | Trainable: False
# Layer: bert.encoder.layer.2.output.dense.bias | Trainable: False
# Layer: bert.encoder.layer.2.output.LayerNorm.weight | Trainable: False
# Layer: bert.encoder.layer.2.output.LayerNorm.bias | Trainable: False
# Layer: bert.encoder.layer.3.attention.self.query.base_layer.weight | Trainable: False
# Layer: bert.encoder.layer.3.attention.self.query.base_layer.bias | Trainable: False
# Layer: bert.encoder.layer.3.attention.self.query.lora_A.adapter.weight | Trainable: True
# Layer: bert.encoder.layer.3.attention.self.query.lora_B.adapter.weight | Trainable: True
# Layer: bert.encoder.layer.3.attention.self.key.weight | Trainable: False
# Layer: bert.encoder.layer.3.attention.self.key.bias | Trainable: False
# Layer: bert.encoder.layer.3.attention.self.value.base_layer.weight | Trainable: False
# Layer: bert.encoder.layer.3.attention.self.value.base_layer.bias | Trainable: False
# Layer: bert.encoder.layer.3.attention.self.value.lora_A.adapter.weight | Trainable: True
# Layer: bert.encoder.layer.3.attention.self.value.lora_B.adapter.weight | Trainable: True
# Layer: bert.encoder.layer.3.attention.output.dense.weight | Trainable: False
# Layer: bert.encoder.layer.3.attention.output.dense.bias | Trainable: False
# Layer: bert.encoder.layer.3.attention.output.LayerNorm.weight | Trainable: False
# Layer: bert.encoder.layer.3.attention.output.LayerNorm.bias | Trainable: False
# Layer: bert.encoder.layer.3.intermediate.dense.weight | Trainable: False
# Layer: bert.encoder.layer.3.intermediate.dense.bias | Trainable: False
# Layer: bert.encoder.layer.3.output.dense.weight | Trainable: False
# Layer: bert.encoder.layer.3.output.dense.bias | Trainable: False
# Layer: bert.encoder.layer.3.output.LayerNorm.weight | Trainable: False
# Layer: bert.encoder.layer.3.output.LayerNorm.bias | Trainable: False
# Layer: bert.encoder.layer.4.attention.self.query.base_layer.weight | Trainable: False
# Layer: bert.encoder.layer.4.attention.self.query.base_layer.bias | Trainable: False
# Layer: bert.encoder.layer.4.attention.self.query.lora_A.adapter.weight | Trainable: True
# Layer: bert.encoder.layer.4.attention.self.query.lora_B.adapter.weight | Trainable: True
# Layer: bert.encoder.layer.4.attention.self.key.weight | Trainable: False
# Layer: bert.encoder.layer.4.attention.self.key.bias | Trainable: False
# Layer: bert.encoder.layer.4.attention.self.value.base_layer.weight | Trainable: False
# Layer: bert.encoder.layer.4.attention.self.value.base_layer.bias | Trainable: False
# Layer: bert.encoder.layer.4.attention.self.value.lora_A.adapter.weight | Trainable: True
# Layer: bert.encoder.layer.4.attention.self.value.lora_B.adapter.weight | Trainable: True
# Layer: bert.encoder.layer.4.attention.output.dense.weight | Trainable: False
# Layer: bert.encoder.layer.4.attention.output.dense.bias | Trainable: False
# Layer: bert.encoder.layer.4.attention.output.LayerNorm.weight | Trainable: False
# Layer: bert.encoder.layer.4.attention.output.LayerNorm.bias | Trainable: False
# Layer: bert.encoder.layer.4.intermediate.dense.weight | Trainable: False
# Layer: bert.encoder.layer.4.intermediate.dense.bias | Trainable: False
# Layer: bert.encoder.layer.4.output.dense.weight | Trainable: False
# Layer: bert.encoder.layer.4.output.dense.bias | Trainable: False
# Layer: bert.encoder.layer.4.output.LayerNorm.weight | Trainable: False
# Layer: bert.encoder.layer.4.output.LayerNorm.bias | Trainable: False
# Layer: bert.encoder.layer.5.attention.self.query.base_layer.weight | Trainable: False
# Layer: bert.encoder.layer.5.attention.self.query.base_layer.bias | Trainable: False
# Layer: bert.encoder.layer.5.attention.self.query.lora_A.adapter.weight | Trainable: True
# Layer: bert.encoder.layer.5.attention.self.query.lora_B.adapter.weight | Trainable: True
# Layer: bert.encoder.layer.5.attention.self.key.weight | Trainable: False
# Layer: bert.encoder.layer.5.attention.self.key.bias | Trainable: False
# Layer: bert.encoder.layer.5.attention.self.value.base_layer.weight | Trainable: False
# Layer: bert.encoder.layer.5.attention.self.value.base_layer.bias | Trainable: False
# Layer: bert.encoder.layer.5.attention.self.value.lora_A.adapter.weight | Trainable: True
# Layer: bert.encoder.layer.5.attention.self.value.lora_B.adapter.weight | Trainable: True
# Layer: bert.encoder.layer.5.attention.output.dense.weight | Trainable: False
# Layer: bert.encoder.layer.5.attention.output.dense.bias | Trainable: False
# Layer: bert.encoder.layer.5.attention.output.LayerNorm.weight | Trainable: False
# Layer: bert.encoder.layer.5.attention.output.LayerNorm.bias | Trainable: False
# Layer: bert.encoder.layer.5.intermediate.dense.weight | Trainable: False
# Layer: bert.encoder.layer.5.intermediate.dense.bias | Trainable: False
# Layer: bert.encoder.layer.5.output.dense.weight | Trainable: False
# Layer: bert.encoder.layer.5.output.dense.bias | Trainable: False
# Layer: bert.encoder.layer.5.output.LayerNorm.weight | Trainable: False
# Layer: bert.encoder.layer.5.output.LayerNorm.bias | Trainable: False
# Layer: bert.encoder.layer.6.attention.self.query.base_layer.weight | Trainable: False
# Layer: bert.encoder.layer.6.attention.self.query.base_layer.bias | Trainable: False
# Layer: bert.encoder.layer.6.attention.self.query.lora_A.adapter.weight | Trainable: True
# Layer: bert.encoder.layer.6.attention.self.query.lora_B.adapter.weight | Trainable: True
# Layer: bert.encoder.layer.6.attention.self.key.weight | Trainable: False
# Layer: bert.encoder.layer.6.attention.self.key.bias | Trainable: False
# Layer: bert.encoder.layer.6.attention.self.value.base_layer.weight | Trainable: False
# Layer: bert.encoder.layer.6.attention.self.value.base_layer.bias | Trainable: False
# Layer: bert.encoder.layer.6.attention.self.value.lora_A.adapter.weight | Trainable: True
# Layer: bert.encoder.layer.6.attention.self.value.lora_B.adapter.weight | Trainable: True
# Layer: bert.encoder.layer.6.attention.output.dense.weight | Trainable: False
# Layer: bert.encoder.layer.6.attention.output.dense.bias | Trainable: False
# Layer: bert.encoder.layer.6.attention.output.LayerNorm.weight | Trainable: False
# Layer: bert.encoder.layer.6.attention.output.LayerNorm.bias | Trainable: False
# Layer: bert.encoder.layer.6.intermediate.dense.weight | Trainable: False
# Layer: bert.encoder.layer.6.intermediate.dense.bias | Trainable: False
# Layer: bert.encoder.layer.6.output.dense.weight | Trainable: False
# Layer: bert.encoder.layer.6.output.dense.bias | Trainable: False
# Layer: bert.encoder.layer.6.output.LayerNorm.weight | Trainable: False
# Layer: bert.encoder.layer.6.output.LayerNorm.bias | Trainable: False
# Layer: bert.encoder.layer.7.attention.self.query.base_layer.weight | Trainable: False
# Layer: bert.encoder.layer.7.attention.self.query.base_layer.bias | Trainable: False
# Layer: bert.encoder.layer.7.attention.self.query.lora_A.adapter.weight | Trainable: True
# Layer: bert.encoder.layer.7.attention.self.query.lora_B.adapter.weight | Trainable: True
# Layer: bert.encoder.layer.7.attention.self.key.weight | Trainable: False
# Layer: bert.encoder.layer.7.attention.self.key.bias | Trainable: False
# Layer: bert.encoder.layer.7.attention.self.value.base_layer.weight | Trainable: False
# Layer: bert.encoder.layer.7.attention.self.value.base_layer.bias | Trainable: False
# Layer: bert.encoder.layer.7.attention.self.value.lora_A.adapter.weight | Trainable: True
# Layer: bert.encoder.layer.7.attention.self.value.lora_B.adapter.weight | Trainable: True
# Layer: bert.encoder.layer.7.attention.output.dense.weight | Trainable: False
# Layer: bert.encoder.layer.7.attention.output.dense.bias | Trainable: False
# Layer: bert.encoder.layer.7.attention.output.LayerNorm.weight | Trainable: False
# Layer: bert.encoder.layer.7.attention.output.LayerNorm.bias | Trainable: False
# Layer: bert.encoder.layer.7.intermediate.dense.weight | Trainable: False
# Layer: bert.encoder.layer.7.intermediate.dense.bias | Trainable: False
# Layer: bert.encoder.layer.7.output.dense.weight | Trainable: False
# Layer: bert.encoder.layer.7.output.dense.bias | Trainable: False
# Layer: bert.encoder.layer.7.output.LayerNorm.weight | Trainable: False
# Layer: bert.encoder.layer.7.output.LayerNorm.bias | Trainable: False
# Layer: bert.encoder.layer.8.attention.self.query.base_layer.weight | Trainable: False
# Layer: bert.encoder.layer.8.attention.self.query.base_layer.bias | Trainable: False
# Layer: bert.encoder.layer.8.attention.self.query.lora_A.adapter.weight | Trainable: True
# Layer: bert.encoder.layer.8.attention.self.query.lora_B.adapter.weight | Trainable: True
# Layer: bert.encoder.layer.8.attention.self.key.weight | Trainable: False
# Layer: bert.encoder.layer.8.attention.self.key.bias | Trainable: False
# Layer: bert.encoder.layer.8.attention.self.value.base_layer.weight | Trainable: False
# Layer: bert.encoder.layer.8.attention.self.value.base_layer.bias | Trainable: False
# Layer: bert.encoder.layer.8.attention.self.value.lora_A.adapter.weight | Trainable: True
# Layer: bert.encoder.layer.8.attention.self.value.lora_B.adapter.weight | Trainable: True
# Layer: bert.encoder.layer.8.attention.output.dense.weight | Trainable: False
# Layer: bert.encoder.layer.8.attention.output.dense.bias | Trainable: False
# Layer: bert.encoder.layer.8.attention.output.LayerNorm.weight | Trainable: False
# Layer: bert.encoder.layer.8.attention.output.LayerNorm.bias | Trainable: False
# Layer: bert.encoder.layer.8.intermediate.dense.weight | Trainable: False
# Layer: bert.encoder.layer.8.intermediate.dense.bias | Trainable: False
# Layer: bert.encoder.layer.8.output.dense.weight | Trainable: False
# Layer: bert.encoder.layer.8.output.dense.bias | Trainable: False
# Layer: bert.encoder.layer.8.output.LayerNorm.weight | Trainable: False
# Layer: bert.encoder.layer.8.output.LayerNorm.bias | Trainable: False
# Layer: bert.encoder.layer.9.attention.self.query.base_layer.weight | Trainable: False
# Layer: bert.encoder.layer.9.attention.self.query.base_layer.bias | Trainable: False
# Layer: bert.encoder.layer.9.attention.self.query.lora_A.adapter.weight | Trainable: True
# Layer: bert.encoder.layer.9.attention.self.query.lora_B.adapter.weight | Trainable: True
# Layer: bert.encoder.layer.9.attention.self.key.weight | Trainable: False
# Layer: bert.encoder.layer.9.attention.self.key.bias | Trainable: False
# Layer: bert.encoder.layer.9.attention.self.value.base_layer.weight | Trainable: False
# Layer: bert.encoder.layer.9.attention.self.value.base_layer.bias | Trainable: False
# Layer: bert.encoder.layer.9.attention.self.value.lora_A.adapter.weight | Trainable: True
# Layer: bert.encoder.layer.9.attention.self.value.lora_B.adapter.weight | Trainable: True
# Layer: bert.encoder.layer.9.attention.output.dense.weight | Trainable: False
# Layer: bert.encoder.layer.9.attention.output.dense.bias | Trainable: False
# Layer: bert.encoder.layer.9.attention.output.LayerNorm.weight | Trainable: False
# Layer: bert.encoder.layer.9.attention.output.LayerNorm.bias | Trainable: False
# Layer: bert.encoder.layer.9.intermediate.dense.weight | Trainable: False
# Layer: bert.encoder.layer.9.intermediate.dense.bias | Trainable: False
# Layer: bert.encoder.layer.9.output.dense.weight | Trainable: False
# Layer: bert.encoder.layer.9.output.dense.bias | Trainable: False
# Layer: bert.encoder.layer.9.output.LayerNorm.weight | Trainable: False
# Layer: bert.encoder.layer.9.output.LayerNorm.bias | Trainable: False
# Layer: bert.encoder.layer.10.attention.self.query.base_layer.weight | Trainable: False
# Layer: bert.encoder.layer.10.attention.self.query.base_layer.bias | Trainable: False
# Layer: bert.encoder.layer.10.attention.self.query.lora_A.adapter.weight | Trainable: True
# Layer: bert.encoder.layer.10.attention.self.query.lora_B.adapter.weight | Trainable: True
# Layer: bert.encoder.layer.10.attention.self.key.weight | Trainable: False
# Layer: bert.encoder.layer.10.attention.self.key.bias | Trainable: False
# Layer: bert.encoder.layer.10.attention.self.value.base_layer.weight | Trainable: False
# Layer: bert.encoder.layer.10.attention.self.value.base_layer.bias | Trainable: False
# Layer: bert.encoder.layer.10.attention.self.value.lora_A.adapter.weight | Trainable: True
# Layer: bert.encoder.layer.10.attention.self.value.lora_B.adapter.weight | Trainable: True
# Layer: bert.encoder.layer.10.attention.output.dense.weight | Trainable: False
# Layer: bert.encoder.layer.10.attention.output.dense.bias | Trainable: False
# Layer: bert.encoder.layer.10.attention.output.LayerNorm.weight | Trainable: False
# Layer: bert.encoder.layer.10.attention.output.LayerNorm.bias | Trainable: False
# Layer: bert.encoder.layer.10.intermediate.dense.weight | Trainable: False
# Layer: bert.encoder.layer.10.intermediate.dense.bias | Trainable: False
# Layer: bert.encoder.layer.10.output.dense.weight | Trainable: False
# Layer: bert.encoder.layer.10.output.dense.bias | Trainable: False
# Layer: bert.encoder.layer.10.output.LayerNorm.weight | Trainable: False
# Layer: bert.encoder.layer.10.output.LayerNorm.bias | Trainable: False
# Layer: bert.encoder.layer.11.attention.self.query.base_layer.weight | Trainable: False
# Layer: bert.encoder.layer.11.attention.self.query.base_layer.bias | Trainable: False
# Layer: bert.encoder.layer.11.attention.self.query.lora_A.adapter.weight | Trainable: True
# Layer: bert.encoder.layer.11.attention.self.query.lora_B.adapter.weight | Trainable: True
# Layer: bert.encoder.layer.11.attention.self.key.weight | Trainable: False
# Layer: bert.encoder.layer.11.attention.self.key.bias | Trainable: False
# Layer: bert.encoder.layer.11.attention.self.value.base_layer.weight | Trainable: False
# Layer: bert.encoder.layer.11.attention.self.value.base_layer.bias | Trainable: False
# Layer: bert.encoder.layer.11.attention.self.value.lora_A.adapter.weight | Trainable: True
# Layer: bert.encoder.layer.11.attention.self.value.lora_B.adapter.weight | Trainable: True
# Layer: bert.encoder.layer.11.attention.output.dense.weight | Trainable: False
# Layer: bert.encoder.layer.11.attention.output.dense.bias | Trainable: False
# Layer: bert.encoder.layer.11.attention.output.LayerNorm.weight | Trainable: False
# Layer: bert.encoder.layer.11.attention.output.LayerNorm.bias | Trainable: False
# Layer: bert.encoder.layer.11.intermediate.dense.weight | Trainable: False
# Layer: bert.encoder.layer.11.intermediate.dense.bias | Trainable: False
# Layer: bert.encoder.layer.11.output.dense.weight | Trainable: False
# Layer: bert.encoder.layer.11.output.dense.bias | Trainable: False
# Layer: bert.encoder.layer.11.output.LayerNorm.weight | Trainable: False
# Layer: bert.encoder.layer.11.output.LayerNorm.bias | Trainable: False
# Layer: bert.pooler.dense.weight | Trainable: False
# Layer: bert.pooler.dense.bias | Trainable: False
# Layer: classifier.weight | Trainable: True
# Layer: classifier.bias | Trainable: True
# Total parameters: 178444802
# Trainable parameters: 591362

# %%
# Set training arguments
training_args = TrainingArguments(
    output_dir='/kaggle/working/results',
    num_train_epochs=3,
    per_device_train_batch_size=32,
    per_device_eval_batch_size=32,
    warmup_ratio=0.1,
    weight_decay=0.01,
    learning_rate=2e-5,
    eval_strategy="epoch",
    save_strategy='epoch',
)

# Initialize Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=train_dataset,
    compute_metrics=compute_metrics
)

# Fine-tune the model
trainer.train()

# Save the fine-tuned model
model.save_pretrained('/kaggle/working/fine_tuned_model')
tokenizer.save_pretrained('/kaggle/working/fine_tuned_model')
# Out:
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# wandb: Currently logged in as: luizanigogosova (luezzka). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.18.3
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20241107_152921-jc2c2x35
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run /kaggle/working/results
# wandb: ⭐️ View project at https://wandb.ai/luezzka/huggingface
# wandb: 🚀 View run at https://wandb.ai/luezzka/huggingface/runs/jc2c2x35
#     <div>
#
#       <progress value='22515' max='22515' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [22515/22515 2:29:07, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.239000</td>
#       <td>0.238675</td>
#       <td>0.902236</td>
#       <td>0.905797</td>
#       <td>0.910848</td>
#       <td>0.902236</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.191100</td>
#       <td>0.199223</td>
#       <td>0.932199</td>
#       <td>0.931922</td>
#       <td>0.931664</td>
#       <td>0.932199</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.173800</td>
#       <td>0.181089</td>
#       <td>0.941002</td>
#       <td>0.939997</td>
#       <td>0.939330</td>
#       <td>0.941002</td>
#     </tr>
#   </tbody>
# </table><p>
# /opt/conda/lib/python3.10/site-packages/transformers/integrations/peft.py:397: FutureWarning: The `active_adapter` method is deprecated and will be removed in a future version.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/integrations/peft.py:397: FutureWarning: The `active_adapter` method is deprecated and will be removed in a future version.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/integrations/peft.py:397: FutureWarning: The `active_adapter` method is deprecated and will be removed in a future version.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/integrations/peft.py:397: FutureWarning: The `active_adapter` method is deprecated and will be removed in a future version.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/integrations/peft.py:397: FutureWarning: The `active_adapter` method is deprecated and will be removed in a future version.
#   warnings.warn(
# ('/kaggle/working/fine_tuned_model/tokenizer_config.json',
#  '/kaggle/working/fine_tuned_model/special_tokens_map.json',
#  '/kaggle/working/fine_tuned_model/vocab.txt',
#  '/kaggle/working/fine_tuned_model/added_tokens.json',
#  '/kaggle/working/fine_tuned_model/tokenizer.json')

# %%
test_df = pd.read_csv('/kaggle/input/wb_winter_24/test.csv', index_col='ID')
#test_df = all_preprocessing(test_df)

model.eval()  # Set model to evaluation mode

def predict(text):
    # Tokenize input text
    inputs = tokenizer(text, padding=True, truncation=True, max_length=256, return_tensors="pt")
    inputs = {key: value.to(device) for key, value in inputs.items()}

    # Perform inference
    with torch.no_grad():
        outputs = model(**inputs)
        logits = outputs.logits
        predictions = torch.argmax(logits, dim=-1)

    return predictions.item()  # Return predicted label (0 or 1 for binary classification)

test_df['label'] = test_df['text'].apply(predict)
test_df = test_df.drop(columns='text')
test_df.to_csv('/kaggle/working/test_predicted.csv')

# %% [markdown]
# # BERT embeddings + CNN
